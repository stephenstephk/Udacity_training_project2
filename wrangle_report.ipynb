# %% [markdown]
# Rapport de gestion des données
#   ## 1 Etape de la  collecte de données
# À propos du ou des ensembles de données
#
# Dans ce projet je vais  traviller sur des ensembles de donees du compte tweeter WeRateDogs. compte Twitter qui évalue les
# chiens avec un commentaire humoristique sur le chien.
#
# ***Comment j'ai collecter l'ensemble des trois donees**
#
# En utilisant le lien fourni par Udacity, j'ai téléchargé l'archive Twitter WeRateDogs manuellement comme
# twitter_archive_enhanced.csv ensuite je l'ai  importé avec la fonction read_csv dans un dataframe que j'ai nome df_telecharge.
#
# J'ai téléchargé le fichier de prédictions d'images de tweet a partir du lien fourni  en utilisant
# la bibliothèque Requests que j'ai enregiste sous le nom de image_predictions.tsv comme recommande dans la description du projet. Ensuite, j'ai importé ce fichier dans un dataframe Python Pandas nome image_predictions_df
#
# j'ai saisi le code qui devrait servir a la recuperation des donees avec  l'API Twitter puisque l'acces de m'a pas ete accorde lorsque jai suivi les etapes pour la demande d'acces. alors j'ai telecharge le fichier a partir du lien et je l'ai nome
# tweet_json.txt et ensuite jai charge ce fichier et je l'ai convertit en dataframe denome tweet_json_df.
#
#
# # 2. Évaluation des données
# Apres avoir ouvert les fichiers twitter_archive_enhanced.csv et image_predictions.tsv dans excel jai pu identifie 3 probles de qualite dont les valeurs manquantes. aussi certaines colonnes pourrait etre regroupe en un seule collone
#
#
#
# Propreté : les données d'archive Twitter sans aucun doublon (c'est-à-dire les retweets) seront vides
# les colonnes retweeted_status_id, retweeted_status_user_id et retweeted_status_timestamp,
# qui peut être abandonné
# Évaluation programmatique
# j'ai utilise les differetes methodes neccessaire afin de faire sortir tout les autres problemes .
# Ainsi: Le constat global au niveau de tous les donees sont :
#
# ### L'ensemble des trois donees
# 1. **les colonnes tweet_id et id represente la meme chose mais des noms differents/ pareil pour les colonnes text et full_text"**
#
#
# 2. **des Valeurs manquantes dans la colonne expanded_urlset et name **
#
# 3. **La colonne name comporte des valeurs 'a' comme nom de personnes,ce qui est assez etrange**
#
#
#
# 4. **Probleme de type de donees au niveau des colonnes timestamp,tweet_id,retweet_count,favorite_count**
#
# 5. ** Certains tweets sont des re-tweets/réponses qui ne sont pas nécessaires pour l'analyse car ce ne sont pas des tweets
#    originaux**
#
#
# 6. **Certaines collonnes sont pas utiles pour l'analyse **
#
#
# 7. **Il existe des lignes  pour lequels le dénominateur d'évaluation est soit 0 ou est inferieur 10 , ce qui n'est pas valide au reagard de la norme**.
#
#
# 8. **certianes  valeurs du numérateur des notes sont tres largemnt  supérieures à 10 et d'autres sont eagle a 0 . comme 1776 on peut se limiter a 15 comme la plus forte note et considerer toute valeur superieur comme des outliers**
#
#
#
# 9. **La balise html unitile dans la colonne Source: recuperer la vrai source et suprimer les balices**
#
#
# 10. **des collonnes p1,p1_config,p1_dog,p2,p2_config,p2_dog ne sont pas assez explicite pour la comprehension et devrait etre modiffie**
#
#
#
#
# ## - Problemes d'orde detecte
#
#
# ### tous les data frame
#
# - 11.**les collonnes  floofer,doggo,puppo et pupper peuvent doivent etre regroupees en une seule pour representer l'etat du chien**
#
#  - 12. **Les trois tables de données font partie d'un unique jeu de données et doivent être fusionnées.**
#
#
# # 3. Données de nettoyage
#
# Au niveau du netoyage j'ai combine les troid dataframe en un seul denome clean_twitter_archiveet jai utilise les technique de netoyage avec pandas pour traite et corrige tout les problems enumere au niveau de l'evaluation avant de de la stocker sous le format csv avec la fonction to_csv de pandas sous le nom de twitter_archive_master
# Je suis passe donc a la visualisation et jai produit des graphes qui sont explique dans le document act_report.html
